# 2010-02-07   238.36               1.8             0.0             1.0
# 2010-02-07   238.09               2.4             0.0             1.0
# 2010-02-07   237.73               2.4             0.0             1.0
# 2010-02-07   237.20               2.4             0.0             1.0
# 2010-02-07   236.90               2.4             0.0             2.0
# 2010-02-07   236.69               1.8             0.0             0.0
# 2010-02-07   236.54               1.8             0.0             0.0
# 2010-02-07   236.15               1.8             0.0             0.0
# 2010-02-07   235.70               1.8             0.0             0.0
#
#             Sub_metering_3
# Date
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            18.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# ...                    ...
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
#
# [1849280 rows x 9 columns]

# %%
cdf.loc[cdf.duplicated(),:]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Time, Global_active_power, Global_reactive_power, Voltage, Global_intensity, Sub_metering_1, Sub_metering_2, Sub_metering_3]
# Index: []

# %%
#cdf.drop_duplicates(inplace=True)

# %% [markdown]
# # DATA ANALYSIS(sample)

# %%
sample=cdf.iloc[:10000,:]

# %%
sns.pairplot(sample)#patterns of features
# Out:
# D:\anaco\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\anaco\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10000 entries, 2006-12-16 to 2006-12-23
# Data columns (total 9 columns):
# Unnamed: 0               10000 non-null int64
# Time                     10000 non-null object
# Global_active_power      9971 non-null float64
# Global_reactive_power    10000 non-null float64
# Voltage                  10000 non-null float64
# Global_intensity         9947 non-null float64
# Sub_metering_1           9961 non-null float64
# Sub_metering_2           10000 non-null float64
# Sub_metering_3           10000 non-null float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.1+ MB

# %%
sample.describe()
# Out:
#          Unnamed: 0  Global_active_power  Global_reactive_power       Voltage  \
# count  10000.000000          9971.000000           10000.000000  10000.000000
# mean    5000.132200             1.748398               0.118914    241.085876
# std     2887.644642             1.339613               0.111726      3.673339
# min        0.000000             0.194000               0.000000    228.910000
# 25%     2499.750000             0.390000               0.000000    238.500000
# 50%     4999.500000             1.480000               0.100000    241.550000
# 75%     7501.250000             2.574000               0.178000    243.920000
# max    10001.000000             7.884000               0.724000    249.480000
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count       9947.000000     9961.000000    10000.000000    10000.000000
# mean           7.410938        0.888565        2.079400        8.244800
# std            5.641107        5.490118        7.674398        8.735863
# min            0.800000        0.000000        0.000000        0.000000
# 25%            1.800000        0.000000        0.000000        0.000000
# 50%            6.200000        0.000000        0.000000        0.000000
# 75%           10.800000        0.000000        1.000000       17.000000
# max           34.200000       40.000000       73.000000       20.000000

# %%
sample.corr()#checking co-relation of features
# Out:
#                        Unnamed: 0  Global_active_power  Global_reactive_power  \
# Unnamed: 0               1.000000             0.002396               0.001557
# Global_active_power      0.002396             1.000000               0.222265
# Global_reactive_power    0.001557             0.222265               1.000000
# Voltage                  0.071036            -0.714391              -0.150368
# Global_intensity         0.002189             0.998631               0.229415
# Sub_metering_1           0.017218             0.310737               0.046576
# Sub_metering_2          -0.108255             0.305474               0.082986
# Sub_metering_3          -0.024214             0.548929               0.052002
#
#                         Voltage  Global_intensity  Sub_metering_1  \
# Unnamed: 0             0.071036          0.002189        0.017218
# Global_active_power   -0.714391          0.998631        0.310737
# Global_reactive_power -0.150368          0.229415        0.046576
# Voltage                1.000000         -0.718566       -0.223837
# Global_intensity      -0.718566          1.000000        0.314588
# Sub_metering_1        -0.223837          0.314588        1.000000
# Sub_metering_2        -0.162413          0.309392        0.095260
# Sub_metering_3        -0.504960          0.535752        0.112886
#
#                        Sub_metering_2  Sub_metering_3
# Unnamed: 0                  -0.108255       -0.024214
# Global_active_power          0.305474        0.548929
# Global_reactive_power        0.082986        0.052002
# Voltage                     -0.162413       -0.504960
# Global_intensity             0.309392        0.535752
# Sub_metering_1               0.095260        0.112886
# Sub_metering_2               1.000000       -0.046453
# Sub_metering_3              -0.046453        1.000000

# %%
plt.figure(figsize=[15,5])
sns.heatmap(sample.corr(),annot=True)
plt.show()

# %%
sample.isnull().sum()
# Out:
# Unnamed: 0                0
# Time                      0
# Global_active_power      29
# Global_reactive_power     0
# Voltage                   0
# Global_intensity         53
# Sub_metering_1           39
# Sub_metering_2            0
# Sub_metering_3            0
# dtype: int64

# %%
sns.boxplot(sample['Voltage'])

# %%
sns.boxplot(sample['Global_active_power'])

# %%
sns.boxplot(sample['Global_reactive_power'])

# %% [markdown]
# # DATA CLEANING

# %%
sample.drop(['Unnamed: 0','Time','Sub_metering_1','Sub_metering_2','Sub_metering_3'],axis=1,inplace=True)
# Out:
# D:\anaco\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
sample['Global_active_power'].median()
# Out:
# 1.48

# %%
sample['Global_active_power'].fillna(sample['Global_active_power'].median(),inplace=True)
# Out:
# D:\anaco\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
sample['Global_intensity'].fillna(sample['Global_intensity'].median(),inplace=True)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10000 entries, 2006-12-16 to 2006-12-23
# Data columns (total 4 columns):
# Global_active_power      10000 non-null float64
# Global_reactive_power    10000 non-null float64
# Voltage                  10000 non-null float64
# Global_intensity         10000 non-null float64
# dtypes: float64(4)
# memory usage: 710.6 KB

# %% [markdown]
# # DATA TRANFORMATION

# %%
sy=sample['Global_intensity']

# %%
SX=sample[['Global_active_power','Global_reactive_power','Voltage']]

# %% [markdown]
# # PRE PROCESSED DATA SPLITTING

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# D:\anaco\lib\site-packages\sklearn\utils\__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence
# D:\anaco\lib\site-packages\sklearn\model_selection\_split.py:18: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable

# %%
X_train, x_test, y_train, y_test = train_test_split(SX,sy,test_size=0.20,random_state=26)

# %% [markdown]
# # MODELLING

# %%
regr=LinearRegression()
regr.fit(X_train,y_train)
prediction=regr.predict(x_test)
regr.score(X_train,y_train)
# Out:
# 0.9909330391524589

# %% [markdown]
# # RESULTS

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rms=sqrt(mean_squared_error(y_test,prediction))
rms
# Out:
# 0.5338876099804916

# %% [markdown]
# # FULL DATASET LINEAR ALGORITHM

# %% [markdown]
# # DATA ANALYSIS

# %%
#sns.pairplot(cdf)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1849280 entries, 2006-12-16 to 2010-02-07
# Data columns (total 9 columns):
# Unnamed: 0               int64
# Time                     object
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 141.1+ MB

# %%
cdf.corr()#checking co-relation of features
# Out:
#                        Unnamed: 0  Global_active_power  Global_reactive_power  \
# Unnamed: 0               1.000000            -0.021192               0.048311
# Global_active_power     -0.021192             1.000000               0.250001
# Global_reactive_power    0.048311             0.250001               1.000000
# Voltage                  0.278375            -0.397770              -0.116041
# Global_intensity        -0.026335             0.998920               0.268457
# Sub_metering_1          -0.007346             0.485627               0.130711
# Sub_metering_2          -0.034708             0.437460               0.140119
# Sub_metering_3           0.080740             0.634829               0.084316
#
#                         Voltage  Global_intensity  Sub_metering_1  \
# Unnamed: 0             0.278375         -0.026335       -0.007346
# Global_active_power   -0.397770          0.998920        0.485627
# Global_reactive_power -0.116041          0.268457        0.130711
# Voltage                1.000000         -0.409553       -0.196699
# Global_intensity      -0.409553          1.000000        0.490148
# Sub_metering_1        -0.196699          0.490148        1.000000
# Sub_metering_2        -0.168990          0.443356        0.055715
# Sub_metering_3        -0.264535          0.622682        0.104600
#
#                        Sub_metering_2  Sub_metering_3
# Unnamed: 0                  -0.034708        0.080740
# Global_active_power          0.437460        0.634829
# Global_reactive_power        0.140119        0.084316
# Voltage                     -0.168990       -0.264535
# Global_intensity             0.443356        0.622682
# Sub_metering_1               0.055715        0.104600
# Sub_metering_2               1.000000        0.080673
# Sub_metering_3               0.080673        1.000000

# %%
plt.figure(figsize=[15,5])
sns.heatmap(cdf.corr(),annot=True)
plt.show()

# %%
cdf.isnull().sum()
# Out:
# Unnamed: 0                  0
# Time                        0
# Global_active_power      1997
# Global_reactive_power     439
# Voltage                  2004
# Global_intensity         1811
# Sub_metering_1           1202
# Sub_metering_2           1128
# Sub_metering_3            129
# dtype: int64

# %%
cdf.describe()
# Out:
#          Unnamed: 0  Global_active_power  Global_reactive_power       Voltage  \
# count  1.849280e+06         1.847283e+06           1.848841e+06  1.847276e+06
# mean   9.300151e+05         1.109487e+00           1.225881e-01  2.408008e+02
# std    5.369280e+05         1.074531e+00           1.122589e-01  3.285449e+00
# min    0.000000e+00         7.600000e-02           0.000000e+00  2.232000e+02
# 25%    4.662518e+05         3.100000e-01           4.800000e-02  2.389000e+02
# 50%    9.285865e+05         6.200000e-01           1.000000e-01  2.409800e+02
# 75%    1.394411e+06         1.544000e+00           1.920000e-01  2.429000e+02
# max    1.862793e+06         1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      1.847469e+06    1.848078e+06    1.848152e+06    1.849151e+06
# mean       4.701519e+00    1.157207e+00    1.333928e+00    6.527056e+00
# std        4.517695e+00    6.262426e+00    5.960130e+00    8.466702e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# 25%        1.400000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 50%        2.800000e+00    0.000000e+00    0.000000e+00    1.000000e+00
# 75%        6.400000e+00    0.000000e+00    1.000000e+00    1.700000e+01
# max        4.840000e+01    8.800000e+01    8.000000e+01    3.100000e+01

# %%
sns.boxplot(cdf['Voltage'])

# %%
sns.boxplot(cdf['Global_active_power'])

# %%
sns.boxplot(cdf['Global_reactive_power'])

# %%
sns.boxplot(cdf['Global_intensity'])

# %% [markdown]
# # DATA CLEANING

# %%
cdf.drop(['Unnamed: 0','Time','Sub_metering_1','Sub_metering_2','Sub_metering_3'],axis=1,inplace=True)
# Out:
# D:\anaco\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
cdf.shape
# Out:
# (1849280, 4)

# %%
cdf['Global_active_power'].fillna(cdf['Global_active_power'].median(),inplace=True)
# Out:
# D:\anaco\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
cdf['Global_reactive_power'].fillna(cdf['Global_reactive_power'].median(),inplace=True)

# %%
cdf['Voltage'].fillna(cdf['Voltage'].median(),inplace=True)

# %%
cdf['Global_intensity'].fillna(cdf['Global_intensity'].median(),inplace=True)

# %% [markdown]
# # DATA TRANFORMATION

# %%
y=cdf['Global_intensity']

# %%
X=cdf[['Global_active_power','Global_reactive_power','Voltage']]

# %% [markdown]
# # PRE PROCESSED DATA SPLITTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=26)

# %% [markdown]
# # MODELLING

# %%
regr=LinearRegression()
regr.fit(X_train,y_train)
prediction=regr.predict(x_test)
regr.score(X_train,y_train)
# Out:
# 0.9959897913024569

# %% [markdown]
# # RESULTS

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rms=sqrt(mean_squared_error(y_test,prediction))
rms
# Out:
# 5.932587001455036

# %% [markdown]
# # Original dataset

# %% [markdown]
# # FULL DATASET CLASSIFICATION ALGORITHMS

# %%
import pandas as pd
df=pd.read_csv("hpc_breakdowns.csv",parse_dates=['Date'],index_col=['Date'])
bdf=df.iloc[0:-200000,:]

# %%
bdf
# Out:
#             Unnamed: 0      Time  Global_active_power  Global_reactive_power  \
# Date
# 2006-12-16           0  17:24:00                4.216                  0.418
# 2006-12-16           1  17:25:00                5.360                  0.436
# 2006-12-16           2  17:26:00                5.374                  0.498
# 2006-12-16           3  17:27:00                5.388                  0.502
# 2006-12-16           4  17:28:00                3.666                  0.528
# 2006-12-16           5  17:29:00                3.520                  0.522
# 2006-12-16           6  17:30:00                3.702                  0.520
# 2006-12-16           7  17:31:00                3.700                  0.520
# 2006-12-16           8  17:32:00                3.668                  0.510
# 2006-12-16           9  17:33:00                3.662                  0.510
# 2006-12-16          10  17:34:00                4.448                  0.498
# 2006-12-16          11  17:35:00                5.412                  0.470
# 2006-12-16          12  17:36:00                5.224                  0.478
# 2006-12-16          13  17:37:00                5.268                  0.398
# 2006-12-16          14  17:38:00                4.054                  0.422
# 2006-12-16          15  17:39:00                3.384                  0.282
# 2006-12-16          16  17:40:00                3.270                  0.152
# 2006-12-16          17  17:41:00                3.430                  0.156
# 2006-12-16          18  17:42:00                3.266                  0.000
# 2006-12-16          19  17:43:00                3.728                  0.000
# 2006-12-16          20  17:44:00                5.894                  0.000
# 2006-12-16          21  17:45:00                7.706                  0.000
# 2006-12-16          22  17:46:00                7.026                  0.000
# 2006-12-16          23  17:47:00                5.174                  0.000
# 2006-12-16          24  17:48:00                4.474                  0.000
# 2006-12-16          25  17:49:00                3.248                  0.000
# 2006-12-16          26  17:50:00                3.236                  0.000
# 2006-12-16          27  17:51:00                3.228                  0.000
# 2006-12-16          28  17:52:00                3.258                  0.000
# 2006-12-16          29  17:53:00                3.178                  0.000
# ...                ...       ...                  ...                    ...
# 2010-02-07     1862764  07:28:00                0.288                  0.114
# 2010-02-07     1862765  07:29:00                0.290                  0.114
# 2010-02-07     1862766  07:30:00                0.288                  0.112
# 2010-02-07     1862767  07:31:00                0.288                  0.114
# 2010-02-07     1862768  07:32:00                0.286                  0.110
# 2010-02-07     1862769  07:33:00                0.286                  0.108
# 2010-02-07     1862770  07:34:00                0.286                  0.108
# 2010-02-07     1862771  07:35:00                0.286                  0.104
# 2010-02-07   238.91               1.2             0.0             1.0
# 2010-02-07   238.84               1.2             0.0             1.0
# 2010-02-07   238.38               1.2             0.0             2.0
# 2010-02-07   238.24               1.2             0.0             1.0
# 2010-02-07   238.30               1.2             0.0             1.0
# 2010-02-07   238.93               1.2             0.0             1.0
# 2010-02-07   238.04               1.2             0.0             1.0
# 2010-02-07   237.89               1.2             0.0             1.0
# 2010-02-07   238.60               1.6             0.0             1.0
# 2010-02-07   238.41               1.8             0.0             1.0
# 2010-02-07   238.85               1.8             0.0             2.0
# 2010-02-07   238.70               1.8             0.0             1.0
# 2010-02-07   238.54               1.8             0.0             1.0
# 2010-02-07   238.50               1.8             0.0             1.0
# 2010-02-07   238.36               1.8             0.0             1.0
# 2010-02-07   238.09               2.4             0.0             1.0
# 2010-02-07   237.73               2.4             0.0             1.0
# 2010-02-07   237.20               2.4             0.0             1.0
# 2010-02-07   236.90               2.4             0.0             2.0
# 2010-02-07   236.69               1.8             0.0             0.0
# 2010-02-07   236.54               1.8             0.0             0.0
# 2010-02-07   236.15               1.8             0.0             0.0
# 2010-02-07   235.70               1.8             0.0             0.0
#
#             Sub_metering_3
# Date
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            18.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            16.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# 2006-12-16            17.0
# ...                    ...
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             0.0
# 2010-02-07             1.0
# 2010-02-07             1.0
# 2010-02-07             0.0
#
# [1849280 rows x 9 columns]

# %%
bdf.loc[bdf['Global_intensity']<=12,'Global_intensity']=0
# Out:
# D:\anaco\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
bdf.loc[bdf['Global_intensity']>12,'Global_intensity']=1

# %% [markdown]
# # DATA ANALYSIS

# %%
import seaborn as sns
#sns.pairplot(bdf)

# %%
bdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1849280 entries, 2006-12-16 to 2010-02-07
# Data columns (total 9 columns):
# Unnamed: 0               int64
# Time                     object
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 141.1+ MB

# %%
bdf.corr()
# Out:
#                        Unnamed: 0  Global_active_power  Global_reactive_power  \
# Unnamed: 0               1.000000            -0.021192               0.048311
# Global_active_power     -0.021192             1.000000               0.250001
# Global_reactive_power    0.048311             0.250001               1.000000
# Voltage                  0.278375            -0.397770              -0.116041
# Global_intensity        -0.061541             0.728814               0.186890
# Sub_metering_1          -0.007346             0.485627               0.130711
# Sub_metering_2          -0.034708             0.437460               0.140119
# Sub_metering_3           0.080740             0.634829               0.084316
#
#                         Voltage  Global_intensity  Sub_metering_1  \
# Unnamed: 0             0.278375         -0.061541       -0.007346
# Global_active_power   -0.397770          0.728814        0.485627
# Global_reactive_power -0.116041          0.186890        0.130711
# Voltage                1.000000         -0.302190       -0.196699
# Global_intensity      -0.302190          1.000000        0.520081
# Sub_metering_1        -0.196699          0.520081        1.000000
# Sub_metering_2        -0.168990          0.426419        0.055715
# Sub_metering_3        -0.264535          0.261536        0.104600
#
#                        Sub_metering_2  Sub_metering_3
# Unnamed: 0                  -0.034708        0.080740
# Global_active_power          0.437460        0.634829
# Global_reactive_power        0.140119        0.084316
# Voltage                     -0.168990       -0.264535
# Global_intensity             0.426419        0.261536
# Sub_metering_1               0.055715        0.104600
# Sub_metering_2               1.000000        0.080673
# Sub_metering_3               0.080673        1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[15,5])
sns.heatmap(bdf.corr(),annot=True)
plt.show()

# %%
bdf.isnull().sum()
# Out:
# Unnamed: 0                  0
# Time                        0
# Global_active_power      1997
# Global_reactive_power     439
# Voltage                  2004
# Global_intensity         1811
# Sub_metering_1           1202
# Sub_metering_2           1128
# Sub_metering_3            129
# dtype: int64

# %%
bdf.describe()
# Out:
#          Unnamed: 0  Global_active_power  Global_reactive_power       Voltage  \
# count  1.849280e+06         1.847283e+06           1.848841e+06  1.847276e+06
# mean   9.300151e+05         1.109487e+00           1.225881e-01  2.408008e+02
# std    5.369280e+05         1.074531e+00           1.122589e-01  3.285449e+00
# min    0.000000e+00         7.600000e-02           0.000000e+00  2.232000e+02
# 25%    4.662518e+05         3.100000e-01           4.800000e-02  2.389000e+02
# 50%    9.285865e+05         6.200000e-01           1.000000e-01  2.409800e+02
# 75%    1.394411e+06         1.544000e+00           1.920000e-01  2.429000e+02
# max    1.862793e+06         1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      1.847469e+06    1.848078e+06    1.848152e+06    1.849151e+06
# mean       7.246184e-02    1.157207e+00    1.333928e+00    6.527056e+00
# std        2.592511e-01    6.262426e+00    5.960130e+00    8.466702e+00
# min        0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 25%        0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# 50%        0.000000e+00    0.000000e+00    0.000000e+00    1.000000e+00
# 75%        0.000000e+00    0.000000e+00    1.000000e+00    1.700000e+01
# max        1.000000e+00    8.800000e+01    8.000000e+01    3.100000e+01

# %%
sns.boxplot(bdf['Voltage'])

# %%
sns.boxplot(bdf['Global_active_power'])

# %%
sns.boxplot(bdf['Global_reactive_power'])

# %% [markdown]
# # DATA CLEANING

# %%
bdf.drop(['Time','Sub_metering_1','Sub_metering_2','Sub_metering_3'],axis=1,inplace=True)
# Out:
# D:\anaco\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
bdf.shape
# Out:
# (1849280, 5)

# %%
bdf.isnull().sum()
# Out:
# Unnamed: 0                  0
# Global_active_power      1997
# Global_reactive_power     439
# Voltage                  2004
# Global_intensity         1811
# dtype: int64

# %%
bdf['Global_active_power'].fillna(bdf['Global_active_power'].median(),inplace=True)
# Out:
# D:\anaco\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
bdf['Global_reactive_power'].fillna(bdf['Global_reactive_power'].median(),inplace=True)

# %%
bdf['Voltage'].fillna(bdf['Voltage'].median(),inplace=True)

# %%
bdf['Global_intensity'].fillna(bdf['Global_intensity'].median(),inplace=True)

# %%
bdf.isnull().sum()
# Out:
# Unnamed: 0               0
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# dtype: int64

# %%
bdf.shape
# Out:
# (1849280, 5)

# %% [markdown]
# # DATA TRANFORMATION

# %%
ys=bdf['Global_intensity']

# %%
Xs=bdf[['Global_active_power','Global_reactive_power','Voltage']]

# %% [markdown]
# # PREPROCESSED DATA SPLITTING

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import train_test_split
X_train, x_test, y_train, y_test = train_test_split(Xs,ys,test_size=0.30,random_state=26)
X_train=X_train.sample(n=5000)
y_train=y_train.sample(n=5000)

# %% [markdown]
# # Modelling

# %%
ran = RandomForestClassifier(random_state=1)
log = LogisticRegression()
svc = SVC(probability=True)



models = [ran,log,svc]         
scores = []

for mod in models:
    mod.fit(X_train,y_train)
    acc = cross_val_score(mod,X_train,y_train,scoring = "accuracy", cv =5)
    scores.append(acc.mean())

# %%
results = pd.DataFrame({
    'Model': ['Random Forest','Logistic Regression','SVC'],
    'Score': scores})

result_df = results.sort_values(by='Score', ascending=False).reset_index(drop=True)
result_df
# Out:
#                  Model   Score
# 0  Logistic Regression  0.9254
# 1                  SVC  0.9254
# 2        Random Forest  0.9222

# %% [markdown]
# # hyperparameter Tuning

# %%
n_estimators = [10, 25, 50, 75, 100]
max_depth = [3, None]
max_features = [1, 3, 5, 7]
min_samples_split = [2, 4, 6, 8, 10]
min_samples_leaf = [2, 4, 6, 8, 10]

hyperparams = {'n_estimators': n_estimators, 'max_depth': max_depth, 
               'min_samples_split': min_samples_split, 'min_samples_leaf': min_samples_leaf}

gd=GridSearchCV(estimator = RandomForestClassifier(), param_grid = hyperparams, 
                verbose=True,cv=5, scoring = "accuracy")

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_estimator_)
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# 0.9254
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# [Parallel(n_jobs=1)]: Done 1250 out of 1250 | elapsed:  7.4min finished

# %%
import numpy as np
penalty = ['l1', 'l2']
C = np.logspace(0, 4, 10)

hyperparams = {'penalty': penalty, 'C': C}

gd=GridSearchCV(estimator = LogisticRegression(), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy")

gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_estimator_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# 0.9254
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.3s finished

# %%
Cs = [0.001, 0.01, 0.1, 1, 5, 10, 15, 20, 50, 100]
gammas = [0.001, 0.01, 0.1, 1]

hyperparams = {'C': Cs, 'gamma' : gammas}


gd=GridSearchCV(estimator = SVC(probability=True), param_grid = hyperparams, 
                verbose=True, cv=5, scoring = "accuracy")


gd.fit(X_train, y_train)
print(gd.best_score_)
print(gd.best_estimator_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed: 30.2min finished
# 0.9254
# SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
ran = RandomForestClassifier(n_estimators=10,
                             max_depth=3, 
                             max_features=3,
                             min_samples_leaf=2, 
                             min_samples_split=8,  
                             random_state=1)


log = LogisticRegression(C=2.7825594022071245,
                         penalty='l2')

svc = SVC(probability=True)




models = [ran,log,svc]         
scores_v3 = []


for mod in models:
    mod.fit(X_train, y_train)
    acc = cross_val_score(mod, X_train, y_train, scoring = "accuracy", cv=5)
    scores_v3.append(acc.mean())

# %%
results = pd.DataFrame({
    'Model': ['Random Forest','Logistic Regression','SVC',],
    'Original Score': scores,'Score with tuned parameters': scores_v3})

result_df = results.sort_values(by='Score with tuned parameters', ascending=False).reset_index(drop=True)
result_df
# Out:
#                  Model  Original Score  Score with tuned parameters
# 0        Random Forest          0.9222                       0.9254
# 1  Logistic Regression          0.9254                       0.9254
# 2                  SVC          0.9254                       0.9254

# %%
yprediction=log.predict(x_test)

# %%
yactual=y_test

# %% [markdown]
# # RESULTS

# %%
from sklearn.metrics import classification_report# another way of getting score from precision & recall

print(classification_report(yprediction,yactual))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       1.00      0.93      0.96    554784
#         1.0       0.00      0.00      0.00         0
#
# avg / total       1.00      0.93      0.96    554784
# D:\anaco\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(yactual,yprediction))# yactual yprediction in sequence..prediction on top.
# Out:
# [[514685      0]
#  [ 40099      0]]
